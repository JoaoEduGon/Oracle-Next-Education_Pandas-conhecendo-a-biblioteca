# %% [markdown]
# Para praticar os métodos aprendidos no decorrer dessa aula e também aprender novos, vamos realizar algumas análises utilizando um arquivo csv diferente: alunos.csv.
#
# 1) Importe o arquivo alunos.csv e armazene seu conteúdo em um DataFrame Pandas.
#
# 2) Visualize as primeiras 7 linhas do DataFrame e as 5 últimas.
#
# 3) Confira a quantidade de linhas e colunas desse DataFrame.
#
# 4) Explore as colunas do DataFrame e analise os tipos dos dados presentes em cada coluna.
#
# Extra: Calcule algumas estatísticas descritivas básicas dos dados do DataFrame (média, desvio padrão, etc). Dica: pesquise pelo método describe.

# %% [markdown]
# #Descrição
#
# Esse notebook foi construído para realizar os desafios propostos no final de cada aula do curso **Pandas: conhecendo a biblioteca**

# %% [markdown]
# ## Aula 1: Conhecendo a base de dados

# %% [markdown]
# ### Desafio 1
# Importe o arquivo [**alunos.csv**](https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/desafios/alunos.csv) e armazene seu conteúdo em um DataFrame Pandas

# %%
import matplotlib.pyplot as plt
import pandas as pd
url = 'https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/desafios/alunos.csv'

# %%
dados = url
pd.read_csv(url)
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 1         Ana     18    NaN     False
# 2       Cátia     27    2.5     False
# 3       Denis     18    5.0     False
# 4        Beto     21   10.0      True
# 5       Bruna     23    NaN     False
# 6        Dara     21    7.0      True
# 7      Carlos     19    6.0      True
# 8       Alice     35    5.6     False
# 9       Vitor     28    NaN     False
# 10     Daniel     21    NaN     False
# 11       Igor     24    4.5     False
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 14      Paulo     37    NaN     False
# 15     Mylena     29    7.0      True
# 16      Lucas     33    NaN     False
# 17      Nadia     34    8.0      True

# %%
dados = pd.read_csv(url)

# %% [markdown]
# ### Desafio 2
# Visualize as primeiras 7 linhas do DataFrame e as 5 últimas

# %%
dados.head(8)
# Out:
#      Nome  Idade  Notas  Aprovado
# 0     Ary     20    7.5      True
# 1     Ana     18    NaN     False
# 2   Cátia     27    2.5     False
# 3   Denis     18    5.0     False
# 4    Beto     21   10.0      True
# 5   Bruna     23    NaN     False
# 6    Dara     21    7.0      True
# 7  Carlos     19    6.0      True

# %% [markdown]
# ### Desafio 3
# Confira a quantidade de linhas e colunas do DataFrame

# %%
dados.shape
# Out:
# (18, 4)

# %%
dados.columns
# Out:
# Index(['Nome', 'Idade', 'Notas', 'Aprovado'], dtype='object')

# %% [markdown]
# ### Desafio 4
# Explore as colunas do DataFrame e analise os tipos dos dados presentes em cada coluna

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Nome      18 non-null     object
#  1   Idade     18 non-null     int64
#  2   Notas     12 non-null     float64
#  3   Aprovado  18 non-null     bool
# dtypes: bool(1), float64(1), int64(1), object(1)
# memory usage: 582.0+ bytes

# %%
dados[['Nome','Notas','Aprovado']]
# Out:
#          Nome  Notas  Aprovado
# 0         Ary    7.5      True
# 1         Ana    NaN     False
# 2       Cátia    2.5     False
# 3       Denis    5.0     False
# 4        Beto   10.0      True
# 5       Bruna    NaN     False
# 6        Dara    7.0      True
# 7      Carlos    6.0      True
# 8       Alice    5.6     False
# 9       Vitor    NaN     False
# 10     Daniel    NaN     False
# 11       Igor    4.5     False
# 12  Sthefanie    9.5      True
# 13      Mirla    9.0      True
# 14      Paulo    NaN     False
# 15     Mylena    7.0      True
# 16      Lucas    NaN     False
# 17      Nadia    8.0      True

# %% [markdown]
# ### **Extra**
# Calcule algumas estatísticas descritivas básicas dos dados do DataFrame (média, desvio padrão, etc) - Dica: pesquise pelo método **describe**

# %% [markdown]
# ###Media
#
# - Notas
# - Idade

# %%
print(dados['Notas'].mean())
print(dados['Idade'].mean())
# Out:
# 6.8
# 25.5

# %% [markdown]
# ### Desvio Padão
#
# - Notas
# - Idade

# %%
print(dados['Notas'].std())
print(dados['Idade'].std())
# Out:
# 2.204953101954366
# 6.070662334249088

# %% [markdown]
# ### Variância
#
# - Notas
# - Idade

# %%
print(dados['Notas'].var())
print(dados['Idade'].var())
# Out:
# 4.861818181818181
# 36.85294117647059

# %% [markdown]
# ###Mediana
#
# - Notas
# - Idade

# %%
print(dados['Notas'].median())
print(dados['Idade'].median())
# Out:
# 7.0
# 24.5

# %% [markdown]
# O time de ML chegou com algumas demandas de última hora para resolvermos nesse momento da análise exploratória. Essas demandas são:
#
# 1) Calcular a média de quartos por apartamento;
#
# 2) Conferir quantos bairros únicos existem na nossa base de dados;
#
# 3) Analisar quais bairros possuem a média de valor de aluguel mais elevadas;
#
# 4) Criar um gráfico de barras horizontais que apresente os 5 bairros com as médias de valores de aluguel mais elevadas.

# %%
url = 'https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/base-de-dados/aluguel.csv'
dados = pd.read_csv(url, sep=';')

# %%
imoveis_comerciais = ['Conjunto Comercial/Sala',
                      'Prédio Inteiro', 'Loja/Salão',
                      'Galpão/Depósito/Armazém',
                      'Casa Comercial', 'Terreno Padrão',
                      'Loja Shopping/ Ct Comercial',
                      'Box/Garagem', 'Chácara',
                      'Loteamento/Condomínio', 'Sítio',
                      'Pousada/Chalé', 'Hotel', 'Indústria']

# removendo imóveis comerciais
df = dados.query('@imoveis_comerciais not in Tipo')

# selecionando apenas imóveis do tipo apartamento
df = df.query('Tipo == "Apartamento"')

# visualizando a base de dados
df.head()
# Out:
#            Tipo        Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 3   Apartamento        Centro        1      0       0    15   800.0
# 4   Apartamento  Higienópolis        1      0       0    48   800.0
# 5   Apartamento  Vista Alegre        3      1       0    70  1200.0
# 6   Apartamento      Cachambi        2      0       0    50  1300.0
# 10  Apartamento        Centro        1      0       0    36  1200.0
#
#     Condominio  IPTU
# 3        390.0  20.0
# 4        230.0   NaN
# 5          NaN   NaN
# 6        301.0  17.0
# 10         NaN   NaN

# %% [markdown]
# ### Desafio 1
# Calcular a média de quartos por apartamento

# %%
media_quartos = dados.query('Tipo == "Apartamento"')['Quartos'].mean()
print(media_quartos )
# Out:
# 2.481568707761622

# %% [markdown]
# ### Desafio 2
# Conferir quantos bairros únicos existem na nossa base de dados

# %%
numero_bairro = len(dados['Bairro'].unique())
print(numero_bairro)
# Out:
# 162

# %% [markdown]
# ### Desafio 3
# Analisar quais bairros possuem a média de valor de aluguel mais elevadas

# %%
media_valor_aluguel_bairro = dados.groupby('Bairro')['Valor'].mean().sort_values(ascending=True)
print(media_valor_aluguel_bairro.head(10))
# Out:
# Bairro
# Senador Camará       635.000000
# Santíssimo           709.090909
# Magalhães Bastos     726.666667
# Turiaçu              733.333333
# Inhoaíba             738.888889
# Jabour               760.000000
# Vaz Lobo             870.937500
# Engenho da Rainha    883.571429
# Colégio              903.333333
# Cosmos               943.750000
# Name: Valor, dtype: float64

# %% [markdown]
# ### Desafio 4
# Explore as colunas do DataFrame e analise os tipos dos dados presentes em cada coluna

# %%
bairro_valor_alto = media_valor_aluguel_bairro.head(5)

# %%
plt.figure(figsize=(10, 6))
bairro_valor_alto.sort_values().plot(kind='barh', color='skyblue')
plt.xlabel('Média de valor por imóvel (R$)')
plt.title('Top 5, bairros com maior média de aluguel')
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# om base nisso, solucione os problemas propostos abaixo utilizando os conhecimentos adquiridos até aqui.
#
# 1) Verifique se a base de dados possui dados nulos e, caso tenha, realize o tratamento desses dados nulos da forma que achar mais coerente com a situação.
#
# 2) Os alunos "Alice" e "Carlos", não fazem mais parte da turma. Sendo assim, remova-os da base de dados.
#
# 3) Aplique um filtro que selecione apenas os alunos que foram aprovados.
#
# 4) Salve o DataFrame que possui apenas os alunos aprovados em um arquivo csv chamado "alunos_aprovados.csv".

# %% [markdown]
# ### Desafio 1
# Verifique se a base de dados possui dados nulos e caso tenha, realize o tratamento desses dados nulos

# %%
from os import read
import pandas as pd
url = 'https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/desafios/alunos.csv'
dados = pd.read_csv(url)

# %%
dados
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 1         Ana     18    NaN     False
# 2       Cátia     27    2.5     False
# 3       Denis     18    5.0     False
# 4        Beto     21   10.0      True
# 5       Bruna     23    NaN     False
# 6        Dara     21    7.0      True
# 7      Carlos     19    6.0      True
# 8       Alice     35    5.6     False
# 9       Vitor     28    NaN     False
# 10     Daniel     21    NaN     False
# 11       Igor     24    4.5     False
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 14      Paulo     37    NaN     False
# 15     Mylena     29    7.0      True
# 16      Lucas     33    NaN     False
# 17      Nadia     34    8.0      True

# %%
dados.isnull()
# Out:
#      Nome  Idade  Notas  Aprovado
# 0   False  False  False     False
# 1   False  False   True     False
# 2   False  False  False     False
# 3   False  False  False     False
# 4   False  False  False     False
# 5   False  False   True     False
# 6   False  False  False     False
# 7   False  False  False     False
# 8   False  False  False     False
# 9   False  False   True     False
# 10  False  False   True     False
# 11  False  False  False     False
# 12  False  False  False     False
# 13  False  False  False     False
# 14  False  False   True     False
# 15  False  False  False     False
# 16  False  False   True     False
# 17  False  False  False     False

# %%
dados.isnull().sum()
# Out:
# Nome        0
# Idade       0
# Notas       6
# Aprovado    0
# dtype: int64

# %%
dados.fillna(0).head(10)
# Out:
#      Nome  Idade  Notas  Aprovado
# 0     Ary     20    7.5      True
# 1     Ana     18    0.0     False
# 2   Cátia     27    2.5     False
# 3   Denis     18    5.0     False
# 4    Beto     21   10.0      True
# 5   Bruna     23    0.0     False
# 6    Dara     21    7.0      True
# 7  Carlos     19    6.0      True
# 8   Alice     35    5.6     False
# 9   Vitor     28    0.0     False

# %%
dados = dados.fillna(0)

# %%
dados.isnull().sum()
# Out:
# Nome        0
# Idade       0
# Notas       0
# Aprovado    0
# dtype: int64

# %% [markdown]
# ### Desafio 2
# Os alunos "Alice" e "Carlos", não fazem mais parte da turma. Sendo assim, remova-os da base de dados

# %%
dados.drop( index=[7, 8] )
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 1         Ana     18    0.0     False
# 2       Cátia     27    2.5     False
# 3       Denis     18    5.0     False
# 4        Beto     21   10.0      True
# 5       Bruna     23    0.0     False
# 6        Dara     21    7.0      True
# 9       Vitor     28    0.0     False
# 10     Daniel     21    0.0     False
# 11       Igor     24    4.5     False
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 14      Paulo     37    0.0     False
# 15     Mylena     29    7.0      True
# 16      Lucas     33    0.0     False
# 17      Nadia     34    8.0      True

# %%
dados1 = dados.drop( index=[7, 8] )

# %%
dados = dados.drop(index=[7, 8])

# %% [markdown]
# ### Desafio 3
# Aplique um filtro que selecione apenas os alunos que foram aprovados

# %%
#dados.query('Aprovado == True')

# %%
#dados = dados.query('Aprovado == True')

# %% [markdown]
# 4) Salve o DataFrame que possui apenas os alunos aprovados em um arquivo csv chamado "alunos_aprovados.csv".

# %%
#dados.to_csv('Alunos aprovados.csv')

# %% [markdown]
# 1) Os alunos participaram de uma atividade extracurricular e ganharam pontos extras. Esses pontos extras correspondem a 40% da nota atual de cada um deles. Com base nisso, crie uma coluna chamada "Pontos_extras" que contenha os pontos extras de cada aluno, ou seja, 40% da nota atual deles.
#
# 2) Crie mais uma coluna, chamada "Notas_finais" que possua as notas de cada aluno somada com os pontos extras.
#
# 3) Como houve uma pontuação extra, alguns alunos que não tinham sido aprovados antes podem ter sido aprovados agora. Com base nisso, crie uma coluna chamada "Aprovado_final" com os seguintes valores:
#
# True: caso o aluno esteja aprovado (nota final deve ser maior ou igual a 6);
# False: caso o aluno esteja reprovado (nota final deve ser menor que 6).
#
# 4) Faça uma seleção e verifique quais alunos não tinham sido aprovados anteriormente, mas foram aprovados após a soma dos pontos extras.

# %% [markdown]
# ### Desafio 1

# %%
dados['Pontos_extras'] = dados['Notas'] * 0.04
dados.head(10)
# Out:
#       Nome  Idade  Notas  Aprovado  Pontos_extras
# 0      Ary     20    7.5      True           0.30
# 1      Ana     18    0.0     False           0.00
# 2    Cátia     27    2.5     False           0.10
# 3    Denis     18    5.0     False           0.20
# 4     Beto     21   10.0      True           0.40
# 5    Bruna     23    0.0     False           0.00
# 6     Dara     21    7.0      True           0.28
# 9    Vitor     28    0.0     False           0.00
# 10  Daniel     21    0.0     False           0.00
# 11    Igor     24    4.5     False           0.18

# %% [markdown]
# ### Desafio 2

# %%
dados['Notas_finais'] = dados['Pontos_extras'] + dados['Notas']
dados.head()
# Out:
#     Nome  Idade  Notas  Aprovado  Pontos_extras  Notas_finais
# 0    Ary     20    7.5      True            0.3           7.8
# 1    Ana     18    0.0     False            0.0           0.0
# 2  Cátia     27    2.5     False            0.1           2.6
# 3  Denis     18    5.0     False            0.2           5.2
# 4   Beto     21   10.0      True            0.4          10.4

# %% [markdown]
# ### Desafio 3

# %%
dados['Aprovado_final'] = dados['Notas_finais'].apply(lambda x: True if x >= 6 else False)
dados.head(17)
# Out:
#          Nome  Idade  Notas  Aprovado  Pontos_extras  Notas_finais  \
# 0         Ary     20    7.5      True           0.30          7.80
# 1         Ana     18    0.0     False           0.00          0.00
# 2       Cátia     27    2.5     False           0.10          2.60
# 3       Denis     18    5.0     False           0.20          5.20
# 4        Beto     21   10.0      True           0.40         10.40
# 5       Bruna     23    0.0     False           0.00          0.00
# 6        Dara     21    7.0      True           0.28          7.28
# 9       Vitor     28    0.0     False           0.00          0.00
# 10     Daniel     21    0.0     False           0.00          0.00
# 11       Igor     24    4.5     False           0.18          4.68
# 12  Sthefanie     26    9.5      True           0.38          9.88
# 13      Mirla     25    9.0      True           0.36          9.36
# 14      Paulo     37    0.0     False           0.00          0.00
# 15     Mylena     29    7.0      True           0.28          7.28
# 16      Lucas     33    0.0     False           0.00          0.00
# 17      Nadia     34    8.0      True           0.32          8.32
#
#     Aprovado_final
# 0             True
# 1            False
# 2            False
# 3            False
# 4             True
# 5            False
# 6             True
# 9            False
# 10           False
# 11           False
# 12            True
# 13            True
# 14           False
# 15            True
# 16           False
# 17            True

# %% [markdown]
# ### Desafio 4

# %%
selecao = (dados['Aprovado'] == False) & (dados['Aprovado_final'] == True)
dados[selecao].head(10)
# Out:
# Empty DataFrame
# Columns: [Nome, Idade, Notas, Aprovado, Pontos_extras, Notas_finais, Aprovado_final]
# Index: []
